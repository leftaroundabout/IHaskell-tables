-- %%
import IHaskell.Tables.Data

-- %%
tabular [ [ ["Bla", "blubb"]
          , ["Foo", "bar"  ]
          , ["Baz"]
          ]                , [["Muh"]], [["hiss"], ["sting", "qeek"]] ]
-- Out:
-- <div class="IHaskell-table">
--     <style>
--         .IHaskell-table table {
--   border-style: none
-- }
-- .IHaskell-table table td {
--   border-style: none;
--   padding-left: 1.5em
-- }
-- .IHaskell-table table thead {
--   border-bottom-style: solid
-- }
-- .IHaskell-table table tr {
--   border-style: none
-- }
--     </style>
--     <table class="List-List-List-List-Char">
--         <td class="List-List-List-Char">
--             <table>
--                 <tr class="List-List-Char">
--                     <td class="List-Char">
--                         Bla
--                     </td>
--                     <td class="List-Char">
--                         blubb
--                     </td>
--                 </tr>
--                 <tr class="List-List-Char">
--                     <td class="List-Char">
--                         Foo
--                     </td>
--                     <td class="List-Char">
--                         bar
--                     </td>
--                 </tr>
--                 <tr class="List-List-Char">
--                     <td class="List-Char">
--                         Baz
--                     </td>
--                 </tr>
--             </table>
--         </td>
--         <td class="List-List-List-Char">
--             <table>
--                 <tr class="List-List-Char">
--                     <td class="List-Char">
--                         Muh
--                     </td>
--                 </tr>
--             </table>
--         </td>
--         <td class="List-List-List-Char">
--             <table>
--                 <tr class="List-List-Char">
--                     <td class="List-Char">
--                         hiss
--                     </td>
--                 </tr>
--                 <tr class="List-List-Char">
--                     <td class="List-Char">
--                         sting
--                     </td>
--                     <td class="List-Char">
--                         qeek
--                     </td>
--                 </tr>
--             </table>
--         </td>
--     </table>
-- </div>

-- %%
tableWithLegend
    ("Stuff", "fuzz"          )
  [ (     17, "silver bullets")
  , (     42, "lives"         )
  , ( -32768, "overflows"     ) ]  :: Table [(Int, String)]
-- Out:
-- <div class="IHaskell-table">
--     <style>
--         .IHaskell-table table {
--   border-style: none
-- }
-- .IHaskell-table table td {
--   border-style: none;
--   padding-left: 1.5em
-- }
-- .IHaskell-table table thead {
--   border-bottom-style: solid
-- }
-- .IHaskell-table table tr {
--   border-style: none
-- }  .IHaskell-table td.Int {
--   text-align: right
-- }
--     </style>
--     <table class="List-Int-List-Char">
--         <thead>
--             <tr class="Int-List-Char">
--                 <td class="List-Char">
--                     Stuff
--                 </td>
--                 <td class="List-Char">
--                     fuzz
--                 </td>
--             </tr>
--         </thead>
--         <tbody>
--             <tr class="Int-List-Char">
--                 <td class="Int">
--                     17
--                 </td>
--                 <td class="List-Char">
--                     silver bullets
--                 </td>
--             </tr>
--             <tr class="Int-List-Char">
--                 <td class="Int">
--                     42
--                 </td>
--                 <td class="List-Char">
--                     lives
--                 </td>
--             </tr>
--             <tr class="Int-List-Char">
--                 <td class="Int">
--                     -32768
--                 </td>
--                 <td class="List-Char">
--                     overflows
--                 </td>
--             </tr>
--         </tbody>
--     </table>
-- </div>

-- %%
tableWithLegend
    ( ("k","n"), "k^n" )
  [ ( ( k , n ),  k^n  )
  | k <- [1 .. 3 :: Int]
  , n <- [2 .. 4 :: Int] ]
-- Out:
-- <div class="IHaskell-table">
--     <style>
--         .IHaskell-table table {
--   border-style: none
-- }
-- .IHaskell-table table td {
--   border-style: none;
--   padding-left: 1.5em
-- }
-- .IHaskell-table table thead {
--   border-bottom-style: solid
-- }
-- .IHaskell-table table tr {
--   border-style: none
-- } .IHaskell-table td.Int {
--   text-align: right;
--   text-align: right;
--   text-align: right
-- }
--     </style>
--     <table class="List-Int-Int-Int">
--         <thead>
--             <tr class="Int-Int-Int">
--                 <td class="List-Char">
--                     k
--                 </td>
--                 <td class="List-Char">
--                     n
--                 </td>
--                 <td class="List-Char">
--                     k^n
--                 </td>
--             </tr>
--         </thead>
--         <tbody>
--             <tr class="Int-Int-Int">
--                 <td class="Int">
--                     1
--                 </td>
--                 <td class="Int">
--                     2
--                 </td>
--                 <td class="Int">
--                     1
--                 </td>
--             </tr>
--             <tr class="Int-Int-Int">
--                 <td class="Int">
--                     1
--                 </td>
--                 <td class="Int">
--                     3
--                 </td>
--                 <td class="Int">
--                     1
--                 </td>
--             </tr>
--             <tr class="Int-Int-Int">
--                 <td class="Int">
--                     1
--                 </td>
--                 <td class="Int">
--                     4
--                 </td>
--                 <td class="Int">
--                     1
--                 </td>
--             </tr>
--             <tr class="Int-Int-Int">
--                 <td class="Int">
--                     2
--                 </td>
--                 <td class="Int">
--                     2
--                 </td>
--                 <td class="Int">
--                     4
--                 </td>
--             </tr>
--             <tr class="Int-Int-Int">
--                 <td class="Int">
--                     2
--                 </td>
--                 <td class="Int">
--                     3
--                 </td>
--                 <td class="Int">
--                     8
--                 </td>
--             </tr>
--             <tr class="Int-Int-Int">
--                 <td class="Int">
--                     2
--                 </td>
--                 <td class="Int">
--                     4
--                 </td>
--                 <td class="Int">
--                     16
--                 </td>
--             </tr>
--             <tr class="Int-Int-Int">
--                 <td class="Int">
--                     3
--                 </td>
--                 <td class="Int">
--                     2
--                 </td>
--                 <td class="Int">
--                     9
--                 </td>
--             </tr>
--             <tr class="Int-Int-Int">
--                 <td class="Int">
--                     3
--                 </td>
--                 <td class="Int">
--                     3
--                 </td>
--                 <td class="Int">
--                     27
--                 </td>
--             </tr>
--             <tr class="Int-Int-Int">
--                 <td class="Int">
--                     3
--                 </td>
--                 <td class="Int">
--                     4
--                 </td>
--                 <td class="Int">
--                     81
--                 </td>
--             </tr>
--         </tbody>
--     </table>
-- </div>

-- %%
tableWithLegend
     ( ("k","n"), "k^n" )
 [ [ ( ( k , n ),  k^n  )
   | k <- [1 .. 3 :: Int] ]
 | n <- [2 .. 4 :: Int]     ]
-- Out:
-- <div class="IHaskell-table">
--     <style>
--         .IHaskell-table table {
--   border-style: none
-- }
-- .IHaskell-table table td {
--   border-style: none;
--   padding-left: 1.5em
-- }
-- .IHaskell-table table thead {
--   border-bottom-style: solid
-- }
-- .IHaskell-table table tr {
--   border-style: none
-- } .IHaskell-table td.Int {
--   text-align: right;
--   text-align: right;
--   text-align: right
-- }
--     </style>
--     <table class="List-List-Int-Int-Int">
--         <thead>
--             <td class="List-Int-Int-Int">
--                 <table>
--                     <td class="List-Char">
--                         k
--                     </td>
--                     <td class="List-Char">
--                         n
--                     </td>
--                     <td class="List-Char">
--                         k^n
--                     </td>
--                 </table>
--             </td>
--         </thead>
--         <tbody>
--             <td class="List-Int-Int-Int">
--                 <table>
--                     <tr class="Int-Int-Int">
--                         <td class="Int">
--                             1
--                         </td>
--                         <td class="Int">
--                             2
--                         </td>
--                         <td class="Int">
--                             1
--                         </td>
--                     </tr>
--                     <tr class="Int-Int-Int">
--                         <td class="Int">
--                             2
--                         </td>
--                         <td class="Int">
--                             2
--                         </td>
--                         <td class="Int">
--                             4
--                         </td>
--                     </tr>
--                     <tr class="Int-Int-Int">
--                         <td class="Int">
--                             3
--                         </td>
--                         <td class="Int">
--                             2
--                         </td>
--                         <td class="Int">
--                             9
--                         </td>
--                     </tr>
--                 </table>
--             </td>
--             <td class="List-Int-Int-Int">
--                 <table>
--                     <tr class="Int-Int-Int">
--                         <td class="Int">
--                             1
--                         </td>
--                         <td class="Int">
--                             3
--                         </td>
--                         <td class="Int">
--                             1
--                         </td>
--                     </tr>
--                     <tr class="Int-Int-Int">
--                         <td class="Int">
--                             2
--                         </td>
--                         <td class="Int">
--                             3
--                         </td>
--                         <td class="Int">
--                             8
--                         </td>
--                     </tr>
--                     <tr class="Int-Int-Int">
--                         <td class="Int">
--                             3
--                         </td>
--                         <td class="Int">
--                             3
--                         </td>
--                         <td class="Int">
--                             27
--                         </td>
--                     </tr>
--                 </table>
--             </td>
--             <td class="List-Int-Int-Int">
--                 <table>
--                     <tr class="Int-Int-Int">
--                         <td class="Int">
--                             1
--                         </td>
--                         <td class="Int">
--                             4
--                         </td>
--                         <td class="Int">
--                             1
--                         </td>
--                     </tr>
--                     <tr class="Int-Int-Int">
--                         <td class="Int">
--                             2
--                         </td>
--                         <td class="Int">
--                             4
--                         </td>
--                         <td class="Int">
--                             16
--                         </td>
--                     </tr>
--                     <tr class="Int-Int-Int">
--                         <td class="Int">
--                             3
--                         </td>
--                         <td class="Int">
--                             4
--                         </td>
--                         <td class="Int">
--                             81
--                         </td>
--                     </tr>
--                 </table>
--             </td>
--         </tbody>
--     </table>
-- </div>

-- %%
tableWithLegend
      ("n", "eⁿ")
    [ ( n, exp n)
    | n <- [0, 0.2 .. 3]] :: Table [(Double,Double)]
-- Out:
-- <div class="IHaskell-table">
--     <style>
--         .IHaskell-table table {
--   border-style: none
-- }
-- .IHaskell-table table td {
--   border-style: none;
--   padding-left: 1.5em
-- }
-- .IHaskell-table table thead {
--   border-bottom-style: solid
-- }
-- .IHaskell-table table tr {
--   border-style: none
-- } .IHaskell-table td.Double {
--   text-align: left;
--   text-align: left
-- }
--     </style>
--     <table class="List-Double-Double">
--         <thead>
--             <tr class="Double-Double">
--                 <td class="List-Char">
--                     n
--                 </td>
--                 <td class="List-Char">
--                     eⁿ
--                 </td>
--             </tr>
--         </thead>
--         <tbody>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     0
--                 </td>
--                 <td class="Double">
--                     1
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     0.2
--                 </td>
--                 <td class="Double">
--                     1.22<span style="opacity:0.42">1</span><span style="opacity:0.12">4</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     0.4
--                 </td>
--                 <td class="Double">
--                     1.49<span style="opacity:0.42">1</span><span style="opacity:0.12">8</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     0.6<span style="opacity:0.42">0</span><span style="opacity:0.12">0</span>
--                 </td>
--                 <td class="Double">
--                     1.82<span style="opacity:0.42">2</span><span style="opacity:0.12">1</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     0.8
--                 </td>
--                 <td class="Double">
--                     2.22<span style="opacity:0.42">5</span><span style="opacity:0.12">5</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     1.0
--                 </td>
--                 <td class="Double">
--                     2.71<span style="opacity:0.42">8</span><span style="opacity:0.12">3</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     1.2
--                 </td>
--                 <td class="Double">
--                     3.32<span style="opacity:0.42">0</span><span style="opacity:0.12">1</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     1.4
--                 </td>
--                 <td class="Double">
--                     4.0<span style="opacity:0.42">5</span><span style="opacity:0.12">5</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     1.6<span style="opacity:0.42">0</span><span style="opacity:0.12">0</span>
--                 </td>
--                 <td class="Double">
--                     4.9<span style="opacity:0.42">5</span><span style="opacity:0.12">3</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     1.8
--                 </td>
--                 <td class="Double">
--                     6.0<span style="opacity:0.42">5</span><span style="opacity:0.12">0</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     2.0
--                 </td>
--                 <td class="Double">
--                     7.3<span style="opacity:0.42">8</span><span style="opacity:0.12">9</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     2.2
--                 </td>
--                 <td class="Double">
--                     9.0<span style="opacity:0.42">2</span><span style="opacity:0.12">5</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     2.4
--                 </td>
--                 <td class="Double">
--                     11.0<span style="opacity:0.42">2</span><span style="opacity:0.12">3</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     2.6<span style="opacity:0.42">0</span><span style="opacity:0.12">0</span>
--                 </td>
--                 <td class="Double">
--                     13.4<span style="opacity:0.42">6</span><span style="opacity:0.12">4</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     2.8
--                 </td>
--                 <td class="Double">
--                     16.4<span style="opacity:0.42">4</span><span style="opacity:0.12">5</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     3.0
--                 </td>
--                 <td class="Double">
--                     20.0<span style="opacity:0.42">8</span><span style="opacity:0.12">6</span>
--                 </td>
--             </tr>
--         </tbody>
--     </table>
-- </div>

-- %%
tableWithLegend
      ("n", "ln (sin n)")
    [ ( n , log $ sin n)
    | n <- [-0.5, 0 .. 3]] :: Table [(Double,Double)]
-- Out:
-- <div class="IHaskell-table">
--     <style>
--         .IHaskell-table table {
--   border-style: none
-- }
-- .IHaskell-table table td {
--   border-style: none;
--   padding-left: 1.5em
-- }
-- .IHaskell-table table thead {
--   border-bottom-style: solid
-- }
-- .IHaskell-table table tr {
--   border-style: none
-- } .IHaskell-table td.Double {
--   text-align: left;
--   text-align: left
-- }
--     </style>
--     <table class="List-Double-Double">
--         <thead>
--             <tr class="Double-Double">
--                 <td class="List-Char">
--                     n
--                 </td>
--                 <td class="List-Char">
--                     ln (sin n)
--                 </td>
--             </tr>
--         </thead>
--         <tbody>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     -0.5<span style="opacity:0.42">0</span><span style="opacity:0.12">0</span>
--                 </td>
--                 <td class="Double">
--                     NaN
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     0.0
--                 </td>
--                 <td class="Double">
--                     -Infinity
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     0.5
--                 </td>
--                 <td class="Double">
--                     -0.73<span style="opacity:0.42">5</span><span style="opacity:0.12">2</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     1
--                 </td>
--                 <td class="Double">
--                     -0.1<span style="opacity:0.42">7</span><span style="opacity:0.12">3</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     1.5<span style="opacity:0.42">0</span><span style="opacity:0.12">0</span>
--                 </td>
--                 <td class="Double">
--                     -2.5<span style="opacity:0.42">0</span><span style="opacity:0.12">8</span>&middot;<sub>10</sub><sup>-3</sup>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     2.0
--                 </td>
--                 <td class="Double">
--                     -9.5<span style="opacity:0.42">0</span><span style="opacity:0.12">8</span>&middot;<sub>10</sub><sup>-2</sup>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     2.5
--                 </td>
--                 <td class="Double">
--                     -0.51<span style="opacity:0.42">3</span><span style="opacity:0.12">4</span>
--                 </td>
--             </tr>
--             <tr class="Double-Double">
--                 <td class="Double">
--                     3
--                 </td>
--                 <td class="Double">
--                     -1.9<span style="opacity:0.42">5</span><span style="opacity:0.12">8</span>
--                 </td>
--             </tr>
--         </tbody>
--     </table>
-- </div>

-- %%
tabular pi
-- Out:
-- <div class="IHaskell-table">
--     <style>
--         .IHaskell-table table {
--   border-style: none
-- }
-- .IHaskell-table table td {
--   border-style: none;
--   padding-left: 1.5em
-- }
-- .IHaskell-table table thead {
--   border-bottom-style: solid
-- }
-- .IHaskell-table table tr {
--   border-style: none
-- } .IHaskell-table td.Double {
--   text-align: left
-- }
--     </style>
--     <table class="Double">
--         3.1<span style="opacity:0.42">4</span><span style="opacity:0.12">2</span>
--     </table>
-- </div>
