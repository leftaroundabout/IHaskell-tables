-- %%
import IHaskell.Tables.Data

-- %%
tabular [ [ ["Bla", "blubb"]
          , ["Foo", "bar"  ]
          , ["Baz"]
          ]                , [["Muh"]], [["hiss"], ["sting", "qeek"]] ]
-- Out:
-- <table>
--     <td>
--         <table>
--             <tr>
--                 <td>
--                     Bla
--                 </td>
--                 <td>
--                     blubb
--                 </td>
--             </tr>
--             <tr>
--                 <td>
--                     Foo
--                 </td>
--                 <td>
--                     bar
--                 </td>
--             </tr>
--             <tr>
--                 <td>
--                     Baz
--                 </td>
--             </tr>
--         </table>
--     </td>
--     <td>
--         <table>
--             <tr>
--                 <td>
--                     Muh
--                 </td>
--             </tr>
--         </table>
--     </td>
--     <td>
--         <table>
--             <tr>
--                 <td>
--                     hiss
--                 </td>
--             </tr>
--             <tr>
--                 <td>
--                     sting
-- ...

-- %%
tableWithLegend
    ("Stuff", "fuzz"          )
  [ (     17, "silver bullets")
  , (     42, "lives"         )
  , ( -32768, "overflows"     ) ]  :: Table [(Int, String)]
-- Out:
-- <table>
--     <thead>
--         <tr>
--             <td>
--                 Stuff
--             </td>
--             <td>
--                 fuzz
--             </td>
--         </tr>
--     </thead>
--     <tbody>
--         <tr>
--             <td>
--                 17
--             </td>
--             <td>
--                 silver bullets
--             </td>
--         </tr>
--         <tr>
--             <td>
--                 42
--             </td>
--             <td>
--                 lives
--             </td>
--         </tr>
--         <tr>
--             <td>
--                 -32768
--             </td>
--             <td>
--                 overflows
--             </td>
--         </tr>
--     </tbody>
-- </table>

-- %%
tableWithLegend
    ( ("k","n"), "k^n" )
  [ ( ( k , n ),  k^n  )
  | k <- [1 .. 3 :: Int]
  , n <- [2 .. 4 :: Int] ]
-- Out:
-- <table>
--     <thead>
--         <tr>
--             <td>
--                 k
--             </td>
--             <td>
--                 n
--             </td>
--             <td>
--                 k^n
--             </td>
--         </tr>
--     </thead>
--     <tbody>
--         <tr>
--             <td>
--                 1
--             </td>
--             <td>
--                 2
--             </td>
--             <td>
--                 1
--             </td>
--         </tr>
--         <tr>
--             <td>
--                 1
--             </td>
--             <td>
--                 3
--             </td>
--             <td>
--                 1
--             </td>
--         </tr>
--         <tr>
--             <td>
--                 1
--             </td>
--             <td>
--                 4
--             </td>
--             <td>
--                 1
--             </td>
--         </tr>
--         <tr>
--             <td>
--                 2
-- ...

-- %%
tableWithLegend
     ( ("k","n"), "k^n" )
 [ [ ( ( k , n ),  k^n  )
   | k <- [1 .. 3 :: Int] ]
 | n <- [2 .. 4 :: Int]     ]
-- Out:
-- <table>
--     <thead>
--         <td>
--             <table>
--                 <td>
--                     k
--                 </td>
--                 <td>
--                     n
--                 </td>
--                 <td>
--                     k^n
--                 </td>
--             </table>
--         </td>
--     </thead>
--     <tbody>
--         <td>
--             <table>
--                 <tr>
--                     <td>
--                         1
--                     </td>
--                     <td>
--                         2
--                     </td>
--                     <td>
--                         1
--                     </td>
--                 </tr>
--                 <tr>
--                     <td>
--                         2
--                     </td>
--                     <td>
--                         2
--                     </td>
--                     <td>
--                         4
--                     </td>
-- ...
