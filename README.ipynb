-- %%
import IHaskell.Tables.Data

-- %%
tabular [ [ ["Bla", "blubb"]
          , ["Foo", "bar"  ]
          , ["Baz"]
          ]                , [["Muh"]], [["hiss"], ["sting", "qeek"]] ]
-- Out:
-- <table>
--     <td>
--         <table>
--             <tr>
--                 <td>
--                     Bla
--                 </td>
--                 <td>
--                     blubb
--                 </td>
--             </tr>
--             <tr>
--                 <td>
--                     Foo
--                 </td>
--                 <td>
--                     bar
--                 </td>
--             </tr>
--             <tr>
--                 <td>
--                     Baz
--                 </td>
--             </tr>
--         </table>
--     </td>
--     <td>
--         <table>
--             <tr>
--                 <td>
--                     Muh
--                 </td>
--             </tr>
--         </table>
--     </td>
--     <td>
--         <table>
--             <tr>
--                 <td>
--                     hiss
--                 </td>
--             </tr>
--             <tr>
--                 <td>
--                     sting
-- ...
